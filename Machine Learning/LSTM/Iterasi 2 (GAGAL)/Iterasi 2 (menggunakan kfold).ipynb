# %% [markdown]
# Notes:
# pake KFold malah ngestuck training nya, kayanya GPU nya ga cukup

# %%
# %pip install tensorflow

# %%
# !pip install tensorflow opencv-python mediapipe scikit-learn matplotlib

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
import tensorflow as tf

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS , 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()

# %%
draw_landmarks(frame, results)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %%
len(results.face_landmarks.landmark)
# Out:
# 468

# %%
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)

# %%
def extract_keypoints(res):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
result_test = extract_keypoints(results)
result_test.shape
# Out:
# (1662,)

# %%
np.save('0', result_test)

# %%
np.load('0.npy')
# Out:
# array([ 0.41970354,  0.55446333, -0.8655656 , ...,  0.        ,
#         0.        ,  0.        ])

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data') 

# Actions that we try to detect
actions = np.array(['A', 'makan', 'kenapa'])

# Thirty videos worth of data
no_sequences = 30 # 30 video yang akan menjadi bagian dari dataset.

# Videos are going to be 30 frames in length
sequence_length = 30 #30 frame per video yang akan diambil untuk representasi data #ill go back to this: try 40, 50, 60

# Folder start
start_folder = 30

# %%
for action in actions:
    for sequence in range(no_sequences):
        try:
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %%
'''
for action in actions: 
    dirmax = np.max(np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int))
    for sequence in range(1,no_sequences+1):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(dirmax+sequence)))
        except:
            pass
'''
# Out:
# '\nfor action in actions: \n    dirmax = np.max(np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int))\n    for sequence in range(1,no_sequences+1):\n        try: \n            os.makedirs(os.path.join(DATA_PATH, action, str(dirmax+sequence)))\n        except:\n            pass\n'

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)
#                 print(results)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(5000) # <--- Ini adalah timer sleep yang mengatur delay 2000 ms (2 detik)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'A': 0, 'makan': 1, 'kenapa': 2}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
X = np.array(sequences)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)
y_test.shape
# Out:
# (5, 3)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
#Setup Kfold
from sklearn.model_selection import KFold
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
#Training model dengan cross-validation
for fold, (train_idx, val_idx) in enumerate(kf.split(X)):
    X_train, X_val = X[train_idx], X[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])

    # Validation score
    score = model.score(X_val, y_val)
    print(f"Fold {fold + 1}, Validation Score: {score}")
# Out:
# Epoch 1/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - categorical_accuracy: 1.0000 - loss: 3.7967e-07
# Epoch 2/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - categorical_accuracy: 1.0000 - loss: 3.6301e-07
# Epoch 3/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - categorical_accuracy: 1.0000 - loss: 6.1410e-07
# Epoch 4/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - categorical_accuracy: 1.0000 - loss: 3.7522e-07
# Epoch 5/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - categorical_accuracy: 1.0000 - loss: 2.8441e-07
# Epoch 6/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - categorical_accuracy: 1.0000 - loss: 3.2363e-07
# Epoch 7/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - categorical_accuracy: 1.0000 - loss: 3.6668e-07
# Epoch 8/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - categorical_accuracy: 1.0000 - loss: 3.5969e-07
# Epoch 9/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - categorical_accuracy: 1.0000 - loss: 6.0623e-07
# Epoch 10/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - categorical_accuracy: 1.0000 - loss: 3.1334e-07
# Epoch 11/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - categorical_accuracy: 1.0000 - loss: 4.7352e-07
# Epoch 12/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - categorical_accuracy: 1.0000 - loss: 4.7419e-07
# Epoch 13/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - categorical_accuracy: 1.0000 - loss: 3.5964e-07
# Epoch 14/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - categorical_accuracy: 1.0000 - loss: 6.0282e-07
# Epoch 15/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - categorical_accuracy: 1.0000 - loss: 2.3598e-07
# Epoch 16/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - categorical_accuracy: 1.0000 - loss: 5.9464e-07
# Epoch 17/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - categorical_accuracy: 1.0000 - loss: 2.7391e-07
# Epoch 18/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - categorical_accuracy: 1.0000 - loss: 2.7670e-07
# Epoch 19/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - categorical_accuracy: 1.0000 - loss: 5.0229e-07
# Epoch 20/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - categorical_accuracy: 1.0000 - loss: 2.7412e-07
# Epoch 21/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - categorical_accuracy: 1.0000 - loss: 3.5374e-07
# Epoch 22/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - categorical_accuracy: 1.0000 - loss: 5.8575e-07
# Epoch 23/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - categorical_accuracy: 1.0000 - loss: 5.7990e-07
# Epoch 24/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - categorical_accuracy: 1.0000 - loss: 3.4521e-07
# Epoch 25/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - categorical_accuracy: 1.0000 - loss: 2.6662e-07
# Epoch 26/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - categorical_accuracy: 1.0000 - loss: 5.7638e-07
# Epoch 27/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - categorical_accuracy: 1.0000 - loss: 4.2235e-07
# Epoch 28/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - categorical_accuracy: 1.0000 - loss: 4.9313e-07
# Epoch 29/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - categorical_accuracy: 1.0000 - loss: 4.9313e-07
# Epoch 30/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - categorical_accuracy: 1.0000 - loss: 3.4702e-07
# Epoch 31/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - categorical_accuracy: 1.0000 - loss: 3.3921e-07
# Epoch 32/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step - categorical_accuracy: 1.0000 - loss: 4.8739e-07
# Epoch 33/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - categorical_accuracy: 1.0000 - loss: 4.8470e-07
# Epoch 34/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - categorical_accuracy: 1.0000 - loss: 4.1356e-07
# Epoch 35/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - categorical_accuracy: 1.0000 - loss: 3.3672e-07
# Epoch 36/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - categorical_accuracy: 1.0000 - loss: 3.4650e-07
# Epoch 37/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - categorical_accuracy: 1.0000 - loss: 4.4186e-07
# Epoch 38/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - categorical_accuracy: 1.0000 - loss: 5.5672e-07
# Epoch 39/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - categorical_accuracy: 1.0000 - loss: 4.1014e-07
# Epoch 40/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - categorical_accuracy: 1.0000 - loss: 5.5693e-07
# Epoch 41/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - categorical_accuracy: 1.0000 - loss: 4.0942e-07
# Epoch 42/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - categorical_accuracy: 1.0000 - loss: 2.5528e-07
# Epoch 43/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - categorical_accuracy: 1.0000 - loss: 4.6830e-07
# Epoch 44/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - categorical_accuracy: 1.0000 - loss: 4.7518e-07
# Epoch 45/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - categorical_accuracy: 1.0000 - loss: 3.2451e-07
# Epoch 46/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - categorical_accuracy: 1.0000 - loss: 3.2637e-07
# Epoch 47/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - categorical_accuracy: 1.0000 - loss: 4.0590e-07
# Epoch 48/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 192ms/step - categorical_accuracy: 1.0000 - loss: 4.6431e-07
# Epoch 49/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - categorical_accuracy: 1.0000 - loss: 3.9969e-07
# Epoch 50/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - categorical_accuracy: 1.0000 - loss: 4.6524e-07
# Epoch 51/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - categorical_accuracy: 1.0000 - loss: 3.1913e-07
# Epoch 52/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step - categorical_accuracy: 1.0000 - loss: 5.3809e-07
# Epoch 53/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - categorical_accuracy: 1.0000 - loss: 3.1830e-07
# Epoch 54/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - categorical_accuracy: 1.0000 - loss: 5.3809e-07
# Epoch 55/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - categorical_accuracy: 1.0000 - loss: 3.2063e-07
# Epoch 56/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - categorical_accuracy: 1.0000 - loss: 4.5903e-07
# Epoch 57/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - categorical_accuracy: 1.0000 - loss: 5.3458e-07
# Epoch 58/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - categorical_accuracy: 1.0000 - loss: 5.3458e-07
# Epoch 59/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - categorical_accuracy: 1.0000 - loss: 4.1769e-07
# Epoch 60/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - categorical_accuracy: 1.0000 - loss: 4.5469e-07
# Epoch 61/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - categorical_accuracy: 1.0000 - loss: 3.9684e-07
# Epoch 62/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step - categorical_accuracy: 1.0000 - loss: 3.1815e-07
# Epoch 63/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - categorical_accuracy: 1.0000 - loss: 4.5014e-07
# Epoch 64/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - categorical_accuracy: 1.0000 - loss: 3.9136e-07
# Epoch 65/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - categorical_accuracy: 1.0000 - loss: 3.1416e-07
# Epoch 66/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - categorical_accuracy: 1.0000 - loss: 4.5257e-07
# Epoch 67/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - categorical_accuracy: 1.0000 - loss: 4.4662e-07
# Epoch 68/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - categorical_accuracy: 1.0000 - loss: 3.8644e-07
# Epoch 69/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - categorical_accuracy: 1.0000 - loss: 3.8608e-07
# Epoch 70/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - categorical_accuracy: 1.0000 - loss: 4.4941e-07
# Epoch 71/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - categorical_accuracy: 1.0000 - loss: 2.3718e-07
# Epoch 72/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - categorical_accuracy: 1.0000 - loss: 3.8619e-07
# Epoch 73/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - categorical_accuracy: 1.0000 - loss: 3.8722e-07
# Epoch 74/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - categorical_accuracy: 1.0000 - loss: 3.8220e-07
# Epoch 75/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - categorical_accuracy: 1.0000 - loss: 1.9920e-07
# Epoch 76/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - categorical_accuracy: 1.0000 - loss: 5.2190e-07
# Epoch 77/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - categorical_accuracy: 1.0000 - loss: 5.1279e-07
# Epoch 78/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - categorical_accuracy: 1.0000 - loss: 5.1559e-07
# Epoch 79/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - categorical_accuracy: 1.0000 - loss: 4.3606e-07
# Epoch 80/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - categorical_accuracy: 1.0000 - loss: 5.1057e-07
# Epoch 81/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - categorical_accuracy: 1.0000 - loss: 4.3943e-07
# Epoch 82/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - categorical_accuracy: 1.0000 - loss: 3.7667e-07
# Epoch 83/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - categorical_accuracy: 1.0000 - loss: 4.3534e-07
# Epoch 84/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - categorical_accuracy: 1.0000 - loss: 3.0402e-07
# Epoch 85/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - categorical_accuracy: 1.0000 - loss: 5.0565e-07
# Epoch 86/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - categorical_accuracy: 1.0000 - loss: 2.9621e-07
# Epoch 87/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - categorical_accuracy: 1.0000 - loss: 3.7201e-07
# Epoch 88/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - categorical_accuracy: 1.0000 - loss: 2.6361e-07
# Epoch 89/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - categorical_accuracy: 1.0000 - loss: 4.2939e-07
# Epoch 90/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - categorical_accuracy: 1.0000 - loss: 3.0014e-07
# Epoch 91/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - categorical_accuracy: 1.0000 - loss: 3.6580e-07
# Epoch 92/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - categorical_accuracy: 1.0000 - loss: 3.8826e-07
# Epoch 93/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - categorical_accuracy: 1.0000 - loss: 3.9208e-07
# Epoch 94/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - categorical_accuracy: 1.0000 - loss: 2.9430e-07
# Epoch 95/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - categorical_accuracy: 1.0000 - loss: 4.2468e-07
# Epoch 96/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - categorical_accuracy: 1.0000 - loss: 2.9114e-07
# Epoch 97/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - categorical_accuracy: 1.0000 - loss: 4.9593e-07
# Epoch 98/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - categorical_accuracy: 1.0000 - loss: 4.8879e-07
# Epoch 99/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - categorical_accuracy: 1.0000 - loss: 4.9111e-07
# Epoch 100/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - categorical_accuracy: 1.0000 - loss: 2.8995e-07
# Epoch 101/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - categorical_accuracy: 1.0000 - loss: 4.1940e-07
# Epoch 102/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - categorical_accuracy: 1.0000 - loss: 4.1568e-07
# Epoch 103/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step - categorical_accuracy: 1.0000 - loss: 3.7899e-07
# Epoch 104/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - categorical_accuracy: 1.0000 - loss: 4.8480e-07
# Epoch 105/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - categorical_accuracy: 1.0000 - loss: 4.8340e-07
# Epoch 106/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - categorical_accuracy: 1.0000 - loss: 4.1423e-07
# Epoch 107/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - categorical_accuracy: 1.0000 - loss: 2.8384e-07
# Epoch 108/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - categorical_accuracy: 1.0000 - loss: 4.8397e-07
# Epoch 109/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - categorical_accuracy: 1.0000 - loss: 3.5193e-07
# Epoch 110/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - categorical_accuracy: 1.0000 - loss: 2.8638e-07
# Epoch 111/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - categorical_accuracy: 1.0000 - loss: 2.2072e-07
# Epoch 112/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - categorical_accuracy: 1.0000 - loss: 2.8126e-07
# Epoch 113/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - categorical_accuracy: 1.0000 - loss: 4.0336e-07
# Epoch 114/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - categorical_accuracy: 1.0000 - loss: 3.6715e-07
# Epoch 115/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - categorical_accuracy: 1.0000 - loss: 4.6876e-07
# Epoch 116/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - categorical_accuracy: 1.0000 - loss: 4.0264e-07
# Epoch 117/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - categorical_accuracy: 1.0000 - loss: 4.0217e-07
# Epoch 118/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - categorical_accuracy: 1.0000 - loss: 3.9995e-07
# Epoch 119/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - categorical_accuracy: 1.0000 - loss: 3.9866e-07
# Epoch 120/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - categorical_accuracy: 1.0000 - loss: 3.6606e-07
# Epoch 121/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - categorical_accuracy: 1.0000 - loss: 4.6664e-07
# Epoch 122/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - categorical_accuracy: 1.0000 - loss: 3.9457e-07
# Epoch 123/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - categorical_accuracy: 1.0000 - loss: 2.7908e-07
# Epoch 124/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - categorical_accuracy: 1.0000 - loss: 3.4241e-07
# Epoch 125/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - categorical_accuracy: 1.0000 - loss: 1.7731e-07
# Epoch 126/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - categorical_accuracy: 1.0000 - loss: 2.7277e-07
# Epoch 127/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - categorical_accuracy: 1.0000 - loss: 2.7008e-07
# Epoch 128/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - categorical_accuracy: 1.0000 - loss: 4.5774e-07
# Epoch 129/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - categorical_accuracy: 1.0000 - loss: 3.8753e-07
# Epoch 130/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - categorical_accuracy: 1.0000 - loss: 2.3536e-07
# Epoch 131/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - categorical_accuracy: 1.0000 - loss: 3.5550e-07
# Epoch 132/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - categorical_accuracy: 1.0000 - loss: 1.7716e-07
# Epoch 133/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - categorical_accuracy: 1.0000 - loss: 3.2963e-07
# Epoch 134/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - categorical_accuracy: 1.0000 - loss: 2.6351e-07
# Epoch 135/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - categorical_accuracy: 1.0000 - loss: 3.8738e-07
# Epoch 136/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - categorical_accuracy: 1.0000 - loss: 2.0308e-07
# Epoch 137/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - categorical_accuracy: 1.0000 - loss: 2.6232e-07
# Epoch 138/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - categorical_accuracy: 1.0000 - loss: 3.7465e-07
# Epoch 139/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - categorical_accuracy: 1.0000 - loss: 3.7734e-07
# Epoch 140/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - categorical_accuracy: 1.0000 - loss: 3.2249e-07
# Epoch 141/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - categorical_accuracy: 1.0000 - loss: 4.4217e-07
# Epoch 142/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - categorical_accuracy: 1.0000 - loss: 3.4821e-07
# Epoch 143/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - categorical_accuracy: 1.0000 - loss: 2.5984e-07
# Epoch 144/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - categorical_accuracy: 1.0000 - loss: 3.7346e-07
# Epoch 145/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - categorical_accuracy: 1.0000 - loss: 3.1815e-07
# Epoch 146/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - categorical_accuracy: 1.0000 - loss: 4.3643e-07
# Epoch 147/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - categorical_accuracy: 1.0000 - loss: 4.3549e-07
# Epoch 148/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - categorical_accuracy: 1.0000 - loss: 1.9987e-07
# Epoch 149/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - categorical_accuracy: 1.0000 - loss: 3.1685e-07
# Epoch 150/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - categorical_accuracy: 1.0000 - loss: 3.1965e-07
# Epoch 151/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - categorical_accuracy: 1.0000 - loss: 1.9961e-07
# Epoch 152/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - categorical_accuracy: 1.0000 - loss: 3.7144e-07
# Epoch 153/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - categorical_accuracy: 1.0000 - loss: 2.4964e-07
# Epoch 154/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - categorical_accuracy: 1.0000 - loss: 2.5430e-07
# Epoch 155/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - categorical_accuracy: 1.0000 - loss: 3.1261e-07
# Epoch 156/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - categorical_accuracy: 1.0000 - loss: 3.6290e-07
# Epoch 157/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - categorical_accuracy: 1.0000 - loss: 3.6197e-07
# Epoch 158/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - categorical_accuracy: 1.0000 - loss: 3.1297e-07
# Epoch 159/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - categorical_accuracy: 1.0000 - loss: 3.1447e-07
# Epoch 160/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - categorical_accuracy: 1.0000 - loss: 4.1806e-07
# Epoch 161/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - categorical_accuracy: 1.0000 - loss: 3.5799e-07
# Epoch 162/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - categorical_accuracy: 1.0000 - loss: 2.2191e-07
# Epoch 163/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - categorical_accuracy: 1.0000 - loss: 2.4856e-07
# Epoch 164/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - categorical_accuracy: 1.0000 - loss: 3.5390e-07
# Epoch 165/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - categorical_accuracy: 1.0000 - loss: 3.0687e-07
# Epoch 166/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - categorical_accuracy: 1.0000 - loss: 4.1350e-07
# Epoch 167/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - categorical_accuracy: 1.0000 - loss: 4.1314e-07
# Epoch 168/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - categorical_accuracy: 1.0000 - loss: 2.4504e-07
# Epoch 169/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - categorical_accuracy: 1.0000 - loss: 3.2700e-07
# Epoch 170/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - categorical_accuracy: 1.0000 - loss: 2.4468e-07
# Epoch 171/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - categorical_accuracy: 1.0000 - loss: 4.1231e-07
# Epoch 172/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - categorical_accuracy: 1.0000 - loss: 2.4571e-07
# Epoch 173/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - categorical_accuracy: 1.0000 - loss: 2.4209e-07
# Epoch 174/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - categorical_accuracy: 1.0000 - loss: 2.9797e-07
# Epoch 175/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - categorical_accuracy: 1.0000 - loss: 3.2032e-07
# Epoch 176/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - categorical_accuracy: 1.0000 - loss: 3.1996e-07
# Epoch 177/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - categorical_accuracy: 1.0000 - loss: 2.4080e-07
# Epoch 178/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - categorical_accuracy: 1.0000 - loss: 2.4137e-07
# Epoch 179/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - categorical_accuracy: 1.0000 - loss: 1.8559e-07
# Epoch 180/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - categorical_accuracy: 1.0000 - loss: 3.9933e-07
# Epoch 181/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - categorical_accuracy: 1.0000 - loss: 4.0305e-07
# Epoch 182/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - categorical_accuracy: 1.0000 - loss: 2.9559e-07
# Epoch 183/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - categorical_accuracy: 1.0000 - loss: 4.0083e-07
# Epoch 184/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - categorical_accuracy: 1.0000 - loss: 3.4086e-07
# Epoch 185/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - categorical_accuracy: 1.0000 - loss: 3.1106e-07
# Epoch 186/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - categorical_accuracy: 1.0000 - loss: 3.4366e-07
# Epoch 187/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - categorical_accuracy: 1.0000 - loss: 3.3957e-07
# Epoch 188/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - categorical_accuracy: 1.0000 - loss: 2.0499e-07
# Epoch 189/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - categorical_accuracy: 1.0000 - loss: 3.9545e-07
# Epoch 190/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - categorical_accuracy: 1.0000 - loss: 3.3734e-07
# Epoch 191/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - categorical_accuracy: 1.0000 - loss: 3.3921e-07
# Epoch 192/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - categorical_accuracy: 1.0000 - loss: 2.3174e-07
# Epoch 193/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - categorical_accuracy: 1.0000 - loss: 2.8948e-07
# Epoch 194/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - categorical_accuracy: 1.0000 - loss: 2.2988e-07
# Epoch 195/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - categorical_accuracy: 1.0000 - loss: 2.8540e-07
# Epoch 196/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - categorical_accuracy: 1.0000 - loss: 2.3464e-07
# Epoch 197/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - categorical_accuracy: 1.0000 - loss: 1.7561e-07
# Epoch 198/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - categorical_accuracy: 1.0000 - loss: 2.2822e-07
# Epoch 199/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - categorical_accuracy: 1.0000 - loss: 2.2962e-07
# Epoch 200/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - categorical_accuracy: 1.0000 - loss: 3.2938e-07
# Epoch 201/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - categorical_accuracy: 1.0000 - loss: 3.8339e-07
# Epoch 202/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - categorical_accuracy: 1.0000 - loss: 3.2808e-07
# Epoch 203/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - categorical_accuracy: 1.0000 - loss: 3.2493e-07
# Epoch 204/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - categorical_accuracy: 1.0000 - loss: 3.7987e-07
# Epoch 205/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - categorical_accuracy: 1.0000 - loss: 3.2679e-07
# Epoch 206/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - categorical_accuracy: 1.0000 - loss: 2.2434e-07
# Epoch 207/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - categorical_accuracy: 1.0000 - loss: 2.2305e-07
# Epoch 208/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - categorical_accuracy: 1.0000 - loss: 2.7893e-07
# Epoch 209/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - categorical_accuracy: 1.0000 - loss: 2.2584e-07
# Epoch 210/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - categorical_accuracy: 1.0000 - loss: 3.7356e-07
# Epoch 211/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - categorical_accuracy: 1.0000 - loss: 2.9497e-07
# Epoch 212/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - categorical_accuracy: 1.0000 - loss: 3.2011e-07
# Epoch 213/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - categorical_accuracy: 1.0000 - loss: 2.2233e-07
# Epoch 214/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - categorical_accuracy: 1.0000 - loss: 1.7064e-07
# Epoch 215/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - categorical_accuracy: 1.0000 - loss: 2.2150e-07
# Epoch 216/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - categorical_accuracy: 1.0000 - loss: 2.2253e-07
# Epoch 217/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - categorical_accuracy: 1.0000 - loss: 2.7086e-07
# Epoch 218/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - categorical_accuracy: 1.0000 - loss: 2.8912e-07
# Epoch 219/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - categorical_accuracy: 1.0000 - loss: 1.9320e-07
# Epoch 220/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - categorical_accuracy: 1.0000 - loss: 2.1658e-07
# Epoch 221/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - categorical_accuracy: 1.0000 - loss: 2.6465e-07
# Epoch 222/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - categorical_accuracy: 1.0000 - loss: 2.1213e-07
# Epoch 223/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - categorical_accuracy: 1.0000 - loss: 2.6651e-07
# Epoch 224/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - categorical_accuracy: 1.0000 - loss: 2.6465e-07
# Epoch 225/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - categorical_accuracy: 1.0000 - loss: 2.1958e-07
# Epoch 226/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - categorical_accuracy: 1.0000 - loss: 2.6579e-07
# Epoch 227/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - categorical_accuracy: 1.0000 - loss: 2.1689e-07
# Epoch 228/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - categorical_accuracy: 1.0000 - loss: 1.6624e-07
# Epoch 229/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - categorical_accuracy: 1.0000 - loss: 1.8414e-07
# Epoch 230/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - categorical_accuracy: 1.0000 - loss: 3.0558e-07
# Epoch 231/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - categorical_accuracy: 1.0000 - loss: 3.5318e-07
# Epoch 232/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - categorical_accuracy: 1.0000 - loss: 3.5375e-07
# Epoch 233/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - categorical_accuracy: 1.0000 - loss: 1.5874e-07
# Epoch 234/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - categorical_accuracy: 1.0000 - loss: 1.8295e-07
# Epoch 235/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - categorical_accuracy: 1.0000 - loss: 3.4780e-07
# Epoch 236/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - categorical_accuracy: 1.0000 - loss: 2.9714e-07
# Epoch 237/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - categorical_accuracy: 1.0000 - loss: 2.9854e-07
# Epoch 238/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - categorical_accuracy: 1.0000 - loss: 2.0308e-07
# Epoch 239/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - categorical_accuracy: 1.0000 - loss: 2.9668e-07
# Epoch 240/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 189ms/step - categorical_accuracy: 1.0000 - loss: 2.4799e-07
# Epoch 241/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - categorical_accuracy: 1.0000 - loss: 2.0142e-07
# Epoch 242/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - categorical_accuracy: 1.0000 - loss: 3.4298e-07
# Epoch 243/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - categorical_accuracy: 1.0000 - loss: 2.4846e-07
# Epoch 244/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - categorical_accuracy: 1.0000 - loss: 2.0422e-07
# Epoch 245/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - categorical_accuracy: 1.0000 - loss: 3.3890e-07
# Epoch 246/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - categorical_accuracy: 1.0000 - loss: 3.3947e-07
# Epoch 247/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - categorical_accuracy: 1.0000 - loss: 1.7835e-07
# Epoch 248/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - categorical_accuracy: 1.0000 - loss: 2.4727e-07
# Epoch 249/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - categorical_accuracy: 1.0000 - loss: 1.7659e-07
# Epoch 250/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - categorical_accuracy: 1.0000 - loss: 1.9894e-07
# Epoch 251/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - categorical_accuracy: 1.0000 - loss: 1.9615e-07
# Epoch 252/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - categorical_accuracy: 1.0000 - loss: 3.3584e-07
# Epoch 253/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - categorical_accuracy: 1.0000 - loss: 2.9161e-07
# Epoch 254/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - categorical_accuracy: 1.0000 - loss: 2.4375e-07
# Epoch 255/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - categorical_accuracy: 1.0000 - loss: 2.8436e-07
# Epoch 256/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - categorical_accuracy: 1.0000 - loss: 1.7586e-07
# Epoch 257/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - categorical_accuracy: 1.0000 - loss: 3.3139e-07
# Epoch 258/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - categorical_accuracy: 1.0000 - loss: 2.4059e-07
# Epoch 259/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - categorical_accuracy: 1.0000 - loss: 3.3046e-07
# Epoch 260/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - categorical_accuracy: 1.0000 - loss: 2.4023e-07
# Epoch 261/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - categorical_accuracy: 1.0000 - loss: 2.8131e-07
# Epoch 262/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - categorical_accuracy: 1.0000 - loss: 1.4813e-07
# Epoch 263/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - categorical_accuracy: 1.0000 - loss: 2.8038e-07
# Epoch 264/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - categorical_accuracy: 1.0000 - loss: 2.8260e-07
# Epoch 265/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - categorical_accuracy: 1.0000 - loss: 1.9423e-07
# Epoch 266/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - categorical_accuracy: 1.0000 - loss: 1.4730e-07
# Epoch 267/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - categorical_accuracy: 1.0000 - loss: 1.9108e-07
# Epoch 268/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - categorical_accuracy: 1.0000 - loss: 1.8839e-07
# Epoch 269/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - categorical_accuracy: 1.0000 - loss: 1.4518e-07
# Epoch 270/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - categorical_accuracy: 1.0000 - loss: 3.2074e-07
# Epoch 271/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - categorical_accuracy: 1.0000 - loss: 2.3309e-07
# Epoch 272/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - categorical_accuracy: 1.0000 - loss: 2.3505e-07
# Epoch 273/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - categorical_accuracy: 1.0000 - loss: 3.1711e-07
# Epoch 274/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - categorical_accuracy: 1.0000 - loss: 1.8942e-07
# Epoch 275/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - categorical_accuracy: 1.0000 - loss: 1.8823e-07
# Epoch 276/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - categorical_accuracy: 1.0000 - loss: 3.1675e-07
# Epoch 277/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - categorical_accuracy: 1.0000 - loss: 2.7158e-07
# Epoch 278/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - categorical_accuracy: 1.0000 - loss: 3.1453e-07
# Epoch 279/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - categorical_accuracy: 1.0000 - loss: 3.1313e-07
# Epoch 280/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - categorical_accuracy: 1.0000 - loss: 1.4503e-07
# Epoch 281/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - categorical_accuracy: 1.0000 - loss: 1.8694e-07
# Epoch 282/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - categorical_accuracy: 1.0000 - loss: 1.8554e-07
# Epoch 283/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - categorical_accuracy: 1.0000 - loss: 1.6293e-07
# Epoch 284/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - categorical_accuracy: 1.0000 - loss: 1.8156e-07
# Epoch 285/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - categorical_accuracy: 1.0000 - loss: 1.8482e-07
# Epoch 286/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - categorical_accuracy: 1.0000 - loss: 1.4301e-07
# Epoch 287/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - categorical_accuracy: 1.0000 - loss: 3.0692e-07
# Epoch 288/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - categorical_accuracy: 1.0000 - loss: 1.8037e-07
# Epoch 289/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - categorical_accuracy: 1.0000 - loss: 2.6232e-07
# Epoch 290/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - categorical_accuracy: 1.0000 - loss: 2.3868e-07
# Epoch 291/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - categorical_accuracy: 1.0000 - loss: 1.5812e-07
# Epoch 292/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - categorical_accuracy: 1.0000 - loss: 2.6103e-07
# Epoch 293/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - categorical_accuracy: 1.0000 - loss: 1.3939e-07
# Epoch 294/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - categorical_accuracy: 1.0000 - loss: 3.0201e-07
# Epoch 295/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - categorical_accuracy: 1.0000 - loss: 2.5834e-07
# Epoch 296/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - categorical_accuracy: 1.0000 - loss: 2.1746e-07
# Epoch 297/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - categorical_accuracy: 1.0000 - loss: 2.1467e-07
# Epoch 298/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - categorical_accuracy: 1.0000 - loss: 2.5844e-07
# Epoch 299/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - categorical_accuracy: 1.0000 - loss: 2.5296e-07
# Epoch 300/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - categorical_accuracy: 1.0000 - loss: 1.7612e-07
# Epoch 301/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - categorical_accuracy: 1.0000 - loss: 6.1674e-08
# Epoch 702/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - categorical_accuracy: 1.0000 - loss: 1.1569e-07
# Epoch 703/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - categorical_accuracy: 1.0000 - loss: 1.0136e-07
# Epoch 704/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - categorical_accuracy: 1.0000 - loss: 6.6900e-08
# Epoch 705/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - categorical_accuracy: 1.0000 - loss: 1.1207e-07
# Epoch 706/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - categorical_accuracy: 1.0000 - loss: 6.6434e-08
# Epoch 707/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - categorical_accuracy: 1.0000 - loss: 7.0056e-08
# Epoch 708/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - categorical_accuracy: 1.0000 - loss: 9.9030e-08
# Epoch 709/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - categorical_accuracy: 1.0000 - loss: 9.5305e-08
# Epoch 710/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - categorical_accuracy: 1.0000 - loss: 1.1253e-07
# Epoch 711/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - categorical_accuracy: 1.0000 - loss: 7.7714e-08
# Epoch 712/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - categorical_accuracy: 1.0000 - loss: 9.9496e-08
# Epoch 713/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - categorical_accuracy: 1.0000 - loss: 9.9134e-08
# Epoch 714/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - categorical_accuracy: 1.0000 - loss: 9.8203e-08
# Epoch 715/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - categorical_accuracy: 1.0000 - loss: 6.4675e-08
# Epoch 716/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - categorical_accuracy: 1.0000 - loss: 9.8203e-08
# Epoch 717/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - categorical_accuracy: 1.0000 - loss: 6.4675e-08
# Epoch 718/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - categorical_accuracy: 1.0000 - loss: 6.0484e-08
# Epoch 719/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - categorical_accuracy: 1.0000 - loss: 6.6538e-08
# Epoch 720/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - categorical_accuracy: 1.0000 - loss: 7.7714e-08
# Epoch 721/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - categorical_accuracy: 1.0000 - loss: 7.7714e-08
# Epoch 722/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - categorical_accuracy: 1.0000 - loss: 6.4675e-08
# Epoch 723/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - categorical_accuracy: 1.0000 - loss: 1.1253e-07
# Epoch 724/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - categorical_accuracy: 1.0000 - loss: 9.2977e-08
# Epoch 725/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - categorical_accuracy: 1.0000 - loss: 1.0902e-07
# Epoch 726/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - categorical_accuracy: 1.0000 - loss: 6.2916e-08
# Epoch 727/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - categorical_accuracy: 1.0000 - loss: 9.0856e-08
# Epoch 728/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - categorical_accuracy: 1.0000 - loss: 1.0808e-07
# Epoch 729/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - categorical_accuracy: 1.0000 - loss: 9.8203e-08
# Epoch 730/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - categorical_accuracy: 1.0000 - loss: 8.9355e-08
# Epoch 731/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - categorical_accuracy: 1.0000 - loss: 4.9774e-08
# Epoch 732/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - categorical_accuracy: 1.0000 - loss: 6.3019e-08
# Epoch 733/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - categorical_accuracy: 1.0000 - loss: 5.8725e-08
# Epoch 734/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - categorical_accuracy: 1.0000 - loss: 7.4195e-08
# Epoch 735/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - categorical_accuracy: 1.0000 - loss: 9.5512e-08
# Epoch 736/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - categorical_accuracy: 1.0000 - loss: 6.1726e-08
# Epoch 737/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - categorical_accuracy: 1.0000 - loss: 5.7069e-08
# Epoch 738/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - categorical_accuracy: 1.0000 - loss: 6.1726e-08
# Epoch 739/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - categorical_accuracy: 1.0000 - loss: 1.0457e-07
# Epoch 740/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - categorical_accuracy: 1.0000 - loss: 6.1726e-08
# Epoch 741/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - categorical_accuracy: 1.0000 - loss: 6.1726e-08
# Epoch 742/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - categorical_accuracy: 1.0000 - loss: 7.2902e-08
# Epoch 743/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - categorical_accuracy: 1.0000 - loss: 1.0364e-07
# Epoch 744/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - categorical_accuracy: 1.0000 - loss: 5.7535e-08
# Epoch 745/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - categorical_accuracy: 1.0000 - loss: 9.2459e-08
# Epoch 746/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - categorical_accuracy: 1.0000 - loss: 6.1726e-08
# Epoch 747/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - categorical_accuracy: 1.0000 - loss: 9.1528e-08
# Epoch 748/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - categorical_accuracy: 1.0000 - loss: 9.1528e-08
# Epoch 749/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - categorical_accuracy: 1.0000 - loss: 1.0493e-07
# Epoch 750/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - categorical_accuracy: 1.0000 - loss: 1.0141e-07
# Epoch 751/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - categorical_accuracy: 1.0000 - loss: 6.0432e-08
# Epoch 752/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - categorical_accuracy: 1.0000 - loss: 7.1608e-08
# Epoch 753/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - categorical_accuracy: 1.0000 - loss: 5.9035e-08
# Epoch 754/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - categorical_accuracy: 1.0000 - loss: 7.2540e-08
# Epoch 755/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - categorical_accuracy: 1.0000 - loss: 7.0211e-08
# Epoch 756/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - categorical_accuracy: 1.0000 - loss: 7.2540e-08
# Epoch 757/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - categorical_accuracy: 1.0000 - loss: 9.0235e-08
# Epoch 758/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - categorical_accuracy: 1.0000 - loss: 9.1166e-08
# Epoch 759/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - categorical_accuracy: 1.0000 - loss: 1.0048e-07
# Epoch 760/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - categorical_accuracy: 1.0000 - loss: 1.0094e-07
# Epoch 761/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - categorical_accuracy: 1.0000 - loss: 5.9501e-08
# Epoch 762/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - categorical_accuracy: 1.0000 - loss: 5.7742e-08
# Epoch 763/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - categorical_accuracy: 1.0000 - loss: 6.9383e-08
# Epoch 764/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - categorical_accuracy: 1.0000 - loss: 6.9383e-08
# Epoch 765/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - categorical_accuracy: 1.0000 - loss: 7.0315e-08
# Epoch 766/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - categorical_accuracy: 1.0000 - loss: 5.7742e-08
# Epoch 767/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - categorical_accuracy: 1.0000 - loss: 7.0211e-08
# Epoch 768/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - categorical_accuracy: 1.0000 - loss: 8.0301e-08
# Epoch 769/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - categorical_accuracy: 1.0000 - loss: 9.4736e-08
# Epoch 770/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - categorical_accuracy: 1.0000 - loss: 6.5865e-08
# Epoch 771/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - categorical_accuracy: 1.0000 - loss: 9.5667e-08
# Epoch 772/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - categorical_accuracy: 1.0000 - loss: 9.4736e-08
# Epoch 773/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - categorical_accuracy: 1.0000 - loss: 9.4270e-08
# Epoch 774/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - categorical_accuracy: 1.0000 - loss: 8.5785e-08
# Epoch 775/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - categorical_accuracy: 1.0000 - loss: 6.5865e-08
# Epoch 776/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - categorical_accuracy: 1.0000 - loss: 5.6552e-08
# Epoch 777/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - categorical_accuracy: 1.0000 - loss: 5.5621e-08
# Epoch 778/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - categorical_accuracy: 1.0000 - loss: 7.9369e-08
# Epoch 779/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - categorical_accuracy: 1.0000 - loss: 4.0719e-08
# Epoch 780/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - categorical_accuracy: 1.0000 - loss: 8.4492e-08
# Epoch 781/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - categorical_accuracy: 1.0000 - loss: 9.5667e-08
# Epoch 782/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - categorical_accuracy: 1.0000 - loss: 6.8090e-08
# Epoch 783/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - categorical_accuracy: 1.0000 - loss: 9.3443e-08
# Epoch 784/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - categorical_accuracy: 1.0000 - loss: 6.4572e-08
# Epoch 785/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - categorical_accuracy: 1.0000 - loss: 5.6552e-08
# Epoch 786/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - categorical_accuracy: 1.0000 - loss: 5.1430e-08
# Epoch 787/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - categorical_accuracy: 1.0000 - loss: 6.6796e-08
# Epoch 788/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - categorical_accuracy: 1.0000 - loss: 9.4736e-08
# Epoch 789/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - categorical_accuracy: 1.0000 - loss: 6.7728e-08
# Epoch 790/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - categorical_accuracy: 1.0000 - loss: 8.4492e-08
# Epoch 791/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - categorical_accuracy: 1.0000 - loss: 9.2511e-08
# Epoch 792/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - categorical_accuracy: 1.0000 - loss: 5.5258e-08
# Epoch 793/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - categorical_accuracy: 1.0000 - loss: 8.2267e-08
# Epoch 794/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - categorical_accuracy: 1.0000 - loss: 9.2511e-08
# Epoch 795/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - categorical_accuracy: 1.0000 - loss: 9.2511e-08
# Epoch 796/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - categorical_accuracy: 1.0000 - loss: 8.2267e-08
# Epoch 797/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - categorical_accuracy: 1.0000 - loss: 6.5503e-08
# Epoch 798/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - categorical_accuracy: 1.0000 - loss: 8.4492e-08
# Epoch 799/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - categorical_accuracy: 1.0000 - loss: 6.6434e-08
# Epoch 800/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - categorical_accuracy: 1.0000 - loss: 6.4209e-08
# Epoch 801/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - categorical_accuracy: 1.0000 - loss: 6.3278e-08
# Epoch 802/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - categorical_accuracy: 1.0000 - loss: 8.0042e-08
# Epoch 803/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - categorical_accuracy: 1.0000 - loss: 6.3278e-08
# Epoch 804/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - categorical_accuracy: 1.0000 - loss: 7.9576e-08
# Epoch 805/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - categorical_accuracy: 1.0000 - loss: 8.8993e-08
# Epoch 806/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - categorical_accuracy: 1.0000 - loss: 5.1740e-08
# Epoch 807/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - categorical_accuracy: 1.0000 - loss: 8.8993e-08
# Epoch 808/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - categorical_accuracy: 1.0000 - loss: 5.2671e-08
# Epoch 809/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - categorical_accuracy: 1.0000 - loss: 5.2671e-08
# Epoch 810/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - categorical_accuracy: 1.0000 - loss: 7.9680e-08
# Epoch 811/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - categorical_accuracy: 1.0000 - loss: 6.1985e-08
# Epoch 812/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - categorical_accuracy: 1.0000 - loss: 7.8748e-08
# Epoch 813/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - categorical_accuracy: 1.0000 - loss: 5.2671e-08
# Epoch 814/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - categorical_accuracy: 1.0000 - loss: 5.2671e-08
# Epoch 815/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - categorical_accuracy: 1.0000 - loss: 4.7549e-08
# Epoch 816/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - categorical_accuracy: 1.0000 - loss: 8.9821e-08
# Epoch 817/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - categorical_accuracy: 1.0000 - loss: 4.8946e-08
# Epoch 818/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - categorical_accuracy: 1.0000 - loss: 6.1985e-08
# Epoch 819/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - categorical_accuracy: 1.0000 - loss: 8.6665e-08
# Epoch 820/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - categorical_accuracy: 1.0000 - loss: 6.1985e-08
# Epoch 821/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - categorical_accuracy: 1.0000 - loss: 4.8946e-08
# Epoch 822/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - categorical_accuracy: 1.0000 - loss: 4.9877e-08
# Epoch 823/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - categorical_accuracy: 1.0000 - loss: 7.9680e-08
# Epoch 824/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - categorical_accuracy: 1.0000 - loss: 3.9633e-08
# Epoch 825/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - categorical_accuracy: 1.0000 - loss: 5.3603e-08
# Epoch 826/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - categorical_accuracy: 1.0000 - loss: 6.1053e-08
# Epoch 827/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - categorical_accuracy: 1.0000 - loss: 7.9680e-08
# Epoch 828/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - categorical_accuracy: 1.0000 - loss: 7.9680e-08
# Epoch 829/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - categorical_accuracy: 1.0000 - loss: 7.7455e-08
# Epoch 830/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - categorical_accuracy: 1.0000 - loss: 6.0691e-08
# Epoch 831/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - categorical_accuracy: 1.0000 - loss: 6.0691e-08
# Epoch 832/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - categorical_accuracy: 1.0000 - loss: 5.8466e-08
# Epoch 833/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - categorical_accuracy: 1.0000 - loss: 7.4299e-08
# Epoch 834/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - categorical_accuracy: 1.0000 - loss: 7.4299e-08
# Epoch 835/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - categorical_accuracy: 1.0000 - loss: 5.9398e-08
# Epoch 836/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - categorical_accuracy: 1.0000 - loss: 7.0573e-08
# Epoch 837/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - categorical_accuracy: 1.0000 - loss: 5.0084e-08
# Epoch 838/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - categorical_accuracy: 1.0000 - loss: 5.0084e-08
# Epoch 839/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - categorical_accuracy: 1.0000 - loss: 4.5893e-08
# Epoch 840/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - categorical_accuracy: 1.0000 - loss: 5.9398e-08
# Epoch 841/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - categorical_accuracy: 1.0000 - loss: 4.8791e-08
# Epoch 842/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - categorical_accuracy: 1.0000 - loss: 4.7394e-08
# Epoch 843/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - categorical_accuracy: 1.0000 - loss: 5.7173e-08
# Epoch 844/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - categorical_accuracy: 1.0000 - loss: 4.7394e-08
# Epoch 845/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - categorical_accuracy: 1.0000 - loss: 5.7173e-08
# Epoch 846/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - categorical_accuracy: 1.0000 - loss: 4.6100e-08
# Epoch 847/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - categorical_accuracy: 1.0000 - loss: 2.8354e-08
# Epoch 1236/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - categorical_accuracy: 1.0000 - loss: 2.8354e-08
# Epoch 1237/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - categorical_accuracy: 1.0000 - loss: 2.8354e-08
# Epoch 1238/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - categorical_accuracy: 1.0000 - loss: 1.8109e-08
# Epoch 1239/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - categorical_accuracy: 1.0000 - loss: 3.1148e-08
# Epoch 1240/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - categorical_accuracy: 1.0000 - loss: 1.8109e-08
# Epoch 1241/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - categorical_accuracy: 1.0000 - loss: 1.8109e-08
# Epoch 1242/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - categorical_accuracy: 1.0000 - loss: 1.8109e-08
# Epoch 1243/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - categorical_accuracy: 1.0000 - loss: 1.5781e-08
# Epoch 1244/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - categorical_accuracy: 1.0000 - loss: 1.5781e-08
# Epoch 1245/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - categorical_accuracy: 1.0000 - loss: 2.0903e-08
# Epoch 1246/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - categorical_accuracy: 1.0000 - loss: 3.1148e-08
# Epoch 1247/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - categorical_accuracy: 1.0000 - loss: 3.1148e-08
# Epoch 1248/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - categorical_accuracy: 1.0000 - loss: 2.6957e-08
# Epoch 1249/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - categorical_accuracy: 1.0000 - loss: 2.6957e-08
# Epoch 1250/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - categorical_accuracy: 1.0000 - loss: 1.8109e-08
# Epoch 1251/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - categorical_accuracy: 1.0000 - loss: 2.0903e-08
# Epoch 1252/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - categorical_accuracy: 1.0000 - loss: 1.6712e-08
# Epoch 1253/2000
# ...
# Epoch 1358/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - categorical_accuracy: 1.0000 - loss: 2.4473e-08
# Epoch 1359/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - categorical_accuracy: 1.0000 - loss: 2.4473e-08
# Epoch 1360/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - categorical_accuracy: 1.0000 - loss: 1.4229e-08
# Epoch 1361/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - categorical_accuracy: 1.0000 - loss: 1.6091e-08
# Epoch 1362/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - categorical_accuracy: 1.0000 - loss: 1.4229e-08
# Epoch 1363/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - categorical_accuracy: 1.0000 - loss: 1.3297e-08
# Epoch 1364/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - categorical_accuracy: 1.0000 - loss: 1.0038e-08
# Epoch 1365/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - categorical_accuracy: 1.0000 - loss: 2.4473e-08
# Epoch 1366/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - categorical_accuracy: 1.0000 - loss: 2.4473e-08
# Epoch 1367/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - categorical_accuracy: 1.0000 - loss: 1.6091e-08
# Epoch 1368/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - categorical_accuracy: 1.0000 - loss: 1.1900e-08
# Epoch 1369/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - categorical_accuracy: 1.0000 - loss: 1.3297e-08
# Epoch 1370/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - categorical_accuracy: 1.0000 - loss: 2.1679e-08
# Epoch 1371/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - categorical_accuracy: 1.0000 - loss: 2.4473e-08
# Epoch 1372/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - categorical_accuracy: 1.0000 - loss: 2.1679e-08
# Epoch 1373/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - categorical_accuracy: 1.0000 - loss: 1.9454e-08
# Epoch 1374/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - categorical_accuracy: 1.0000 - loss: 2.2248e-08
# Epoch 1375/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - categorical_accuracy: 1.0000 - loss: 9.2097e-09
# Epoch 1376/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - categorical_accuracy: 1.0000 - loss: 1.4798e-08
# Epoch 1377/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - categorical_accuracy: 1.0000 - loss: 1.2935e-08
# Epoch 1378/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - categorical_accuracy: 1.0000 - loss: 9.2097e-09
# Epoch 1379/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - categorical_accuracy: 1.0000 - loss: 1.4798e-08
# Epoch 1380/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - categorical_accuracy: 1.0000 - loss: 2.0386e-08
# Epoch 1381/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - categorical_accuracy: 1.0000 - loss: 1.4798e-08
# Epoch 1382/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - categorical_accuracy: 1.0000 - loss: 1.2935e-08
# Epoch 1383/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - categorical_accuracy: 1.0000 - loss: 1.2935e-08
# Epoch 1384/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - categorical_accuracy: 1.0000 - loss: 1.2935e-08
# Epoch 1385/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - categorical_accuracy: 1.0000 - loss: 1.2935e-08
# Epoch 1386/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - categorical_accuracy: 1.0000 - loss: 2.0386e-08
# Epoch 1387/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - categorical_accuracy: 1.0000 - loss: 2.2248e-08
# Epoch 1388/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - categorical_accuracy: 1.0000 - loss: 1.2935e-08
# Epoch 1389/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - categorical_accuracy: 1.0000 - loss: 1.1072e-08
# Epoch 1390/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - categorical_accuracy: 1.0000 - loss: 1.9454e-08
# Epoch 1391/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - categorical_accuracy: 1.0000 - loss: 1.2935e-08
# Epoch 1392/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - categorical_accuracy: 1.0000 - loss: 1.2004e-08
# Epoch 1393/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - categorical_accuracy: 1.0000 - loss: 2.0386e-08
# Epoch 1394/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - categorical_accuracy: 1.0000 - loss: 9.2097e-09
# Epoch 1395/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - categorical_accuracy: 1.0000 - loss: 2.2248e-08
# Epoch 1396/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - categorical_accuracy: 1.0000 - loss: 1.9454e-08
# Epoch 1397/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - categorical_accuracy: 1.0000 - loss: 2.0386e-08
# Epoch 1398/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - categorical_accuracy: 1.0000 - loss: 1.4798e-08
# Epoch 1399/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - categorical_accuracy: 1.0000 - loss: 1.4798e-08
# Epoch 1400/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - categorical_accuracy: 1.0000 - loss: 1.9454e-08
# Epoch 1401/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - categorical_accuracy: 1.0000 - loss: 1.2004e-08
# Epoch 1402/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - categorical_accuracy: 1.0000 - loss: 2.0386e-08
# Epoch 1403/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - categorical_accuracy: 1.0000 - loss: 2.0386e-08
# Epoch 1404/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - categorical_accuracy: 1.0000 - loss: 2.0386e-08
# Epoch 1405/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - categorical_accuracy: 1.0000 - loss: 2.2248e-08
# Epoch 1406/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - categorical_accuracy: 1.0000 - loss: 1.2004e-08
# Epoch 1407/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - categorical_accuracy: 1.0000 - loss: 2.0386e-08
# Epoch 1408/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - categorical_accuracy: 1.0000 - loss: 1.2935e-08
# Epoch 1409/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - categorical_accuracy: 1.0000 - loss: 2.0386e-08
# Epoch 1410/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - categorical_accuracy: 1.0000 - loss: 2.0386e-08
# Epoch 1411/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - categorical_accuracy: 1.0000 - loss: 1.4798e-08
# Epoch 1412/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - categorical_accuracy: 1.0000 - loss: 2.0386e-08
# Epoch 1413/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - categorical_accuracy: 1.0000 - loss: 1.4798e-08
# Epoch 1414/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - categorical_accuracy: 1.0000 - loss: 2.0386e-08
# Epoch 1415/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - categorical_accuracy: 1.0000 - loss: 1.2935e-08
# Epoch 1416/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - categorical_accuracy: 1.0000 - loss: 1.4798e-08
# Epoch 1417/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - categorical_accuracy: 1.0000 - loss: 2.0386e-08
# Epoch 1418/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - categorical_accuracy: 1.0000 - loss: 2.2248e-08
# Epoch 1419/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - categorical_accuracy: 1.0000 - loss: 1.2935e-08
# Epoch 1420/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - categorical_accuracy: 1.0000 - loss: 2.0386e-08
# Epoch 1421/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - categorical_accuracy: 1.0000 - loss: 1.4798e-08
# Epoch 1422/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - categorical_accuracy: 1.0000 - loss: 2.2248e-08
# Epoch 1423/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - categorical_accuracy: 1.0000 - loss: 1.1072e-08
# Epoch 1424/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - categorical_accuracy: 1.0000 - loss: 1.2935e-08
# Epoch 1425/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - categorical_accuracy: 1.0000 - loss: 1.1072e-08
# Epoch 1426/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - categorical_accuracy: 1.0000 - loss: 2.2248e-08
# Epoch 1427/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - categorical_accuracy: 1.0000 - loss: 1.2935e-08
# Epoch 1428/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - categorical_accuracy: 1.0000 - loss: 2.0386e-08
# Epoch 1429/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - categorical_accuracy: 1.0000 - loss: 1.2004e-08
# Epoch 1430/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - categorical_accuracy: 1.0000 - loss: 1.9454e-08
# Epoch 1431/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - categorical_accuracy: 1.0000 - loss: 1.4798e-08
# Epoch 1432/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - categorical_accuracy: 1.0000 - loss: 1.2935e-08
# Epoch 1433/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - categorical_accuracy: 1.0000 - loss: 1.1072e-08
# Epoch 1434/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - categorical_accuracy: 1.0000 - loss: 1.4798e-08
# Epoch 1435/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - categorical_accuracy: 1.0000 - loss: 2.2248e-08
# Epoch 1436/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - categorical_accuracy: 1.0000 - loss: 1.4798e-08
# Epoch 1437/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - categorical_accuracy: 1.0000 - loss: 1.2935e-08
# Epoch 1438/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - categorical_accuracy: 1.0000 - loss: 1.8161e-08
# Epoch 1439/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - categorical_accuracy: 1.0000 - loss: 1.3504e-08
# Epoch 1440/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - categorical_accuracy: 1.0000 - loss: 1.8161e-08
# Epoch 1441/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - categorical_accuracy: 1.0000 - loss: 1.3866e-08
# Epoch 1442/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - categorical_accuracy: 1.0000 - loss: 1.0245e-08
# Epoch 1443/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - categorical_accuracy: 1.0000 - loss: 1.0710e-08
# Epoch 1444/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - categorical_accuracy: 1.0000 - loss: 1.0245e-08
# Epoch 1445/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - categorical_accuracy: 1.0000 - loss: 2.0023e-08
# Epoch 1446/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - categorical_accuracy: 1.0000 - loss: 1.3504e-08
# Epoch 1447/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - categorical_accuracy: 1.0000 - loss: 1.8161e-08
# Epoch 1448/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - categorical_accuracy: 1.0000 - loss: 1.8161e-08
# Epoch 1449/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - categorical_accuracy: 1.0000 - loss: 1.8161e-08
# Epoch 1450/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - categorical_accuracy: 1.0000 - loss: 1.1642e-08
# Epoch 1451/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - categorical_accuracy: 1.0000 - loss: 1.3504e-08
# Epoch 1452/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - categorical_accuracy: 1.0000 - loss: 2.0023e-08
# Epoch 1453/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - categorical_accuracy: 1.0000 - loss: 1.8161e-08
# Epoch 1454/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - categorical_accuracy: 1.0000 - loss: 1.3504e-08
# Epoch 1455/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - categorical_accuracy: 1.0000 - loss: 2.0023e-08
# Epoch 1456/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - categorical_accuracy: 1.0000 - loss: 1.3504e-08
# Epoch 1457/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - categorical_accuracy: 1.0000 - loss: 1.0245e-08
# Epoch 1458/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - categorical_accuracy: 1.0000 - loss: 1.8161e-08
# Epoch 1459/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - categorical_accuracy: 1.0000 - loss: 1.9454e-08
# Epoch 1460/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - categorical_accuracy: 1.0000 - loss: 1.0245e-08
# Epoch 1461/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - categorical_accuracy: 1.0000 - loss: 1.8161e-08
# Epoch 1462/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - categorical_accuracy: 1.0000 - loss: 2.0023e-08
# Epoch 1463/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - categorical_accuracy: 1.0000 - loss: 1.8161e-08
# Epoch 1464/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - categorical_accuracy: 1.0000 - loss: 7.4506e-09
# Epoch 1465/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - categorical_accuracy: 1.0000 - loss: 2.0023e-08
# Epoch 1466/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - categorical_accuracy: 1.0000 - loss: 1.8161e-08
# Epoch 1467/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - categorical_accuracy: 1.0000 - loss: 8.3819e-09
# Epoch 1468/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - categorical_accuracy: 1.0000 - loss: 1.1642e-08
# Epoch 1469/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - categorical_accuracy: 1.0000 - loss: 1.1642e-08
# Epoch 1470/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - categorical_accuracy: 1.0000 - loss: 2.0023e-08
# Epoch 1471/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - categorical_accuracy: 1.0000 - loss: 1.1642e-08
# Epoch 1472/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - categorical_accuracy: 1.0000 - loss: 1.1642e-08
# Epoch 1473/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - categorical_accuracy: 1.0000 - loss: 2.0023e-08
# Epoch 1474/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - categorical_accuracy: 1.0000 - loss: 1.1642e-08
# Epoch 1475/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - categorical_accuracy: 1.0000 - loss: 1.1642e-08
# Epoch 1476/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - categorical_accuracy: 1.0000 - loss: 2.0023e-08
# Epoch 1477/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - categorical_accuracy: 1.0000 - loss: 1.1642e-08
# Epoch 1478/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - categorical_accuracy: 1.0000 - loss: 2.2248e-08
# Epoch 1479/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - categorical_accuracy: 1.0000 - loss: 1.8161e-08
# Epoch 1480/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - categorical_accuracy: 1.0000 - loss: 1.0245e-08
# Epoch 1481/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - categorical_accuracy: 1.0000 - loss: 8.3819e-09
# Epoch 1482/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - categorical_accuracy: 1.0000 - loss: 1.3504e-08
# Epoch 1483/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - categorical_accuracy: 1.0000 - loss: 1.1642e-08
# Epoch 1484/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - categorical_accuracy: 1.0000 - loss: 2.0023e-08
# Epoch 1485/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - categorical_accuracy: 1.0000 - loss: 8.3819e-09
# Epoch 1486/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - categorical_accuracy: 1.0000 - loss: 1.8161e-08
# Epoch 1487/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - categorical_accuracy: 1.0000 - loss: 1.1642e-08
# Epoch 1488/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - categorical_accuracy: 1.0000 - loss: 1.1642e-08
# Epoch 1489/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - categorical_accuracy: 1.0000 - loss: 1.0710e-08
# Epoch 1490/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - categorical_accuracy: 1.0000 - loss: 1.0245e-08
# Epoch 1491/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - categorical_accuracy: 1.0000 - loss: 1.1642e-08
# Epoch 1492/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - categorical_accuracy: 1.0000 - loss: 1.1642e-08
# Epoch 1493/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - categorical_accuracy: 1.0000 - loss: 2.0386e-08
# Epoch 1494/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - categorical_accuracy: 1.0000 - loss: 1.7229e-08
# Epoch 1495/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - categorical_accuracy: 1.0000 - loss: 8.3819e-09
# Epoch 1496/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - categorical_accuracy: 1.0000 - loss: 1.0710e-08
# Epoch 1497/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - categorical_accuracy: 1.0000 - loss: 1.1642e-08
# Epoch 1498/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - categorical_accuracy: 1.0000 - loss: 1.7229e-08
# Epoch 1499/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - categorical_accuracy: 1.0000 - loss: 2.0023e-08
# Epoch 1500/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - categorical_accuracy: 1.0000 - loss: 2.0023e-08
# Epoch 1501/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - categorical_accuracy: 1.0000 - loss: 2.0023e-08
# Epoch 1502/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - categorical_accuracy: 1.0000 - loss: 1.1642e-08
# Epoch 1503/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - categorical_accuracy: 1.0000 - loss: 1.1642e-08
# Epoch 1504/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - categorical_accuracy: 1.0000 - loss: 1.1642e-08
# Epoch 1505/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - categorical_accuracy: 1.0000 - loss: 1.1642e-08
# Epoch 1506/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - categorical_accuracy: 1.0000 - loss: 1.1642e-08
# Epoch 1507/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - categorical_accuracy: 1.0000 - loss: 1.8161e-08
# Epoch 1508/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - categorical_accuracy: 1.0000 - loss: 2.0023e-08
# Epoch 1509/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - categorical_accuracy: 1.0000 - loss: 1.3504e-08
# Epoch 1510/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - categorical_accuracy: 1.0000 - loss: 1.7229e-08
# Epoch 1511/2000

# %%
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 model.summary()
#
# NameError: name 'model' is not defined

# %%
res = model.predict(X_test)
res
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step
# array([[2.4374719e-10, 3.9311540e-11, 1.0000000e+00],
#        [1.0000000e+00, 2.7344350e-29, 1.1736586e-15],
#        [1.5843405e-05, 9.9998379e-01, 4.2788125e-07],
#        [1.2596293e-12, 3.1850612e-20, 1.0000000e+00],
#        [1.0000000e+00, 6.6486496e-29, 2.4772722e-15]], dtype=float32)

# %%
actions[np.argmax(res[0])]
# Out:
# 'kenapa'

# %%
actions[np.argmax(y_test[0])]
# Out:
# 'kenapa'

# %%
model.save('action.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
del model

# %%
model.load_weights('action.h5')

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)
yhat
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# array([[2.4374719e-10, 3.9311540e-11, 1.0000000e+00],
#        [1.0000000e+00, 2.7344350e-29, 1.1736586e-15],
#        [1.5843405e-05, 9.9998379e-01, 4.2788125e-07],
#        [1.2596293e-12, 3.1850612e-20, 1.0000000e+00],
#        [1.0000000e+00, 6.6486496e-29, 2.4772722e-15]], dtype=float32)

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[3, 0],
#         [0, 2]],
#
#        [[4, 0],
#         [0, 1]],
#
#        [[3, 0],
#         [0, 2]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 1.0

# %%
# 1. New detection variables
sequence = []
sentence = []
threshold = 0.8

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
#        sequence.insert(0,keypoints)
#        sequence = sequence[:30]

        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            
            
        #3. Viz logic
            if res[np.argmax(res)] > threshold: 
                if len(sentence) > 0: 
                    if actions[np.argmax(res)] != sentence[-1]:
                        sentence.append(actions[np.argmax(res)])
                else:
                    sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# makan
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# kenapa
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# kenapa

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
plt.figure(figsize=(18,18))
plt.imshow(prob_viz(res, actions, image, colors))

# %%
len(sequence)
# Out:
# 30

# %%
sequence.append('def')

# %%
sequence.reverse()

# %%
sequence[-30:]
# Out:
# [array([ 0.6038903 ,  0.41388744, -1.2279985 , ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.60337245,  0.41451994, -1.21560073, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.60220885,  0.41456944, -1.17379689, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.60190332,  0.41113275, -0.99926883, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.60180396,  0.41024512, -1.07600796, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.60169554,  0.40947768, -1.12903714, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.60157192,  0.40950358, -1.14857292, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.59778661,  0.40759137, -1.1515907 , ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.5936662 ,  0.40564016, -1.07719994, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.59407914,  0.40055943, -1.11041665, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.59588188,  0.39933869, -1.1447053 , ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.59915119,  0.39864397, -1.1461153 , ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.60369205,  0.39817974, -1.20589352, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.60410249,  0.39820278, -1.18533731, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.60358256,  0.39808762, -1.17814839, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.60334402,  0.39828879, -1.17701256, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.60336691,  0.39889592, -1.17199636, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.60168904,  0.39881179, -1.17984176, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.60047817,  0.39997178, -1.10390842, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.59995455,  0.40064588, -1.09199023, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.59914505,  0.40136528, -1.12173188, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.5972802 ,  0.4028722 , -1.09728456, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.5959993 ,  0.40485445, -1.17807889, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.59538198,  0.4052721 , -1.25540113, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.59123647,  0.40540639, -1.15208721, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.5910567 ,  0.40546724, -1.12957704, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.58863801,  0.40552902, -1.22645414, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.58805645,  0.40564919, -1.24571681, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.58702731,  0.40400189, -1.25898707, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.58578682,  0.40333673, -1.42341173, ...,  0.        ,
#          0.        ,  0.        ])]

# %%
cap.release()
cv2.destroyAllWindows()

# %%
res[np.argmax(res)] > threshold
# Out:
# True

# %%
(num_sequences,30,1662)

# %%
model.predict(np.expand_dims(X_test[0], axis=0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# array([[2.4375091e-10, 3.9314163e-11, 1.0000000e+00]], dtype=float32)
